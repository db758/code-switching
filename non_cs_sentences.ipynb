# %%
import pandas as pd

# %%
df = pd.read_csv('11152019_appended_input_R_v4_new_15_11_2019.csv')

# %%
df.head()
# Out:
#          sent_type university  sent_id aligned_to  \
# 0      code-switch        CMU        2    CMU_296
# 1  non-code-switch        CMU      296      CMU_2
# 2      code-switch        CMU        4   CMU_3006
# 3  non-code-switch        CMU     3006      CMU_4
# 4      code-switch        CMU        5     CMU_70
#
#                                    original_sentence  \
# 0  rich neighborhood ， 非常 安全 （ 这里 属于 富人 区 ） ， 旁边 ...
# 1
# 2                      lease 从 八月 开始 ， 具体 日期 可以 商量 。
# 3
# 4                             house 一共 有 两 层 + 地下室 。
#
#                                          translation  word_id  \
# 0  富人 区 ， 非常 安全 （ 这里 属于 富人 区 ） ， 旁边 就 是 公园 ， 附近 还...        1
# 1  路上 一般 见到 都 是 学生 ， 很少 见到 游民 ， 公寓 对面 是 公园 和 一 个 ...       12
# 2                         租约 从 八月 开始 ， 具体 日期 可以 商量 。        1
# 3               房子 的 照片 在 附件 中 ， 还有 好多 照片 放 不 上来 啦 。        3
# 4                                房子 一共 有 两 层 + 地下室 。        1
#
#   first_cs_word_form first_cs_word_translation  \
# ...

# %%
non_cs = df.loc[df['sent_type'] == 'non-code-switch']

# %%
non_cs.head()
# Out:
#          sent_type university  sent_id aligned_to original_sentence  \
# 1  non-code-switch        CMU      296      CMU_2
# 3  non-code-switch        CMU     3006      CMU_4
# 5  non-code-switch        CMU       70      CMU_5
# 7  non-code-switch        CMU     6777      CMU_6
# 9  non-code-switch        CMU     4373      CMU_9
#
#                                          translation  word_id  \
# 1  路上 一般 见到 都 是 学生 ， 很少 见到 游民 ， 公寓 对面 是 公园 和 一 个 ...       12
# 3               房子 的 照片 在 附件 中 ， 还有 好多 照片 放 不 上来 啦 。        3
# 5                                    房子 共 有 三 个 厕所 。        1
# 7                                    没有 找到 寄存 的 地方 。        5
# 9                                    全部 木头 地板 ， 干净 。        2
#
#   first_cs_word_form first_cs_word_translation  \
# 1                NaN                        公寓
# 3                NaN                        照片
# 5                NaN                        房子
# 7                NaN                        地方
# ...

# %%
non_cs.to_csv('non_cs_sentences.csv')
